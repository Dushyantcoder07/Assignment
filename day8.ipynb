# %%
import pandas as pd

df = pd.DataFrame({
    'Col1':range(12),
    'Col2':['A']*3+['B']*3+['C']*3+['D']*3,
    'Date':pd.to_datetime(['2026-01-01','2026-01-02','2026-01-03']*4)
})

print(df)
# Out:
#     Col1 Col2       Date
# 0      0    A 2026-01-01
# 1      1    A 2026-01-02
# 2      2    A 2026-01-03
# 3      3    B 2026-01-01
# 4      4    B 2026-01-02
# 5      5    B 2026-01-03
# 6      6    C 2026-01-01
# 7      7    C 2026-01-02
# 8      8    C 2026-01-03
# 9      9    D 2026-01-01
# 10    10    D 2026-01-02
# 11    11    D 2026-01-03

# %%
data={
    'Course':
['cs','civil','CS','civil','cs'],
'Year':[1,2,1,1,2],
'Student':[100,150,120,90,180]
}
df= pd.DataFrame(data)
df['Marks']=df['Student'][:3]
print(df)
# Out:
#   Course  Year  Student  Marks
# 0     cs     1      100  100.0
# 1  civil     2      150  150.0
# 2     CS     1      120  120.0
# 3  civil     1       90    NaN
# 4     cs     2      180    NaN

# %%
import pandas as pd
import numpy as np

data={
    'Col1': [2,np.nan,np.nan,4],
    'Col2': [1,pd.NA,5,pd.NA]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    Col1  Col2
# 0   2.0     1
# 1   NaN  <NA>
# 2   NaN     5
# 3   4.0  <NA>
