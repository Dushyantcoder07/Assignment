# %%
import numpy as np

print(np.__version__)
# Out:
# 2.4.6

# %%
import numpy as np

a=np.array([[1,2,3,4,5],
            [11,13,14,15,12]])
print(a,type(a))
# Out:
# [[ 1  2  3  4  5]
#  [11 13 14 15 12]] <class 'numpy.ndarray'>

# %%
import numpy as np 

a= np.array([
    1,2,3
],dtype='S')

print(a,type(a),a.dtype)
# Out:
# [b'1' b'2' b'3'] <class 'numpy.ndarray'> |S1

# %%
import numpy as np

array1= np.linespace(0,5,num=10)
print("array!:",array)

array2=np.linespace
