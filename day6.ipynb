# %%
import pandas as pd

data = [10,20,30,40]

ps = pd.Series(data, index={'a','b','c','d'})
print(ps)
print(type(ps))
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# <class 'pandas.Series'>
