# %%
price=200
tax=0.18
print(f"price is {price}and tax is{tax}")
# Out:
# price is 200and tax is0.18

# %%
a="dushyant"
b="sisodiya"
print(a+b)
print(a,b)
# Out:
# dushyantsisodiya
# dushyant sisodiya

# %%
a="hello"
print(a.upper())
print(a.title())
# Out:
# HELLO
# Hello

# %%
a="dushyant"
print(a.center(60))
# Out:
#                           dushyant

# %%
a="dushyant is a good person"
print(a.count(a))
# Out:
# 1

# %%
#endwith()
#endtabs()
#find()
#index()
a="dushyant is good"
b="yes"
print(a.find("is"))
print(a.index("is"))
print(a.isalpha())
# Out:
# 9
# 9
# False

# %%
s="-"
seq=("a","b","c")
print(s.join(seq))
# Out:
# a-b-c

# %%
a="    dushyant        "
print((a.lstrip(' ')).rstrip(" "))
# Out:
# dushyant

# %%
#istrip
#replace
#splitines
#translate
#maketrans

# %%
a="dushyant is"
print(a.replace("is",'are'))
# Out:
# dushyant are

# %%
a="this is python"
b="thiz"
if(b not in a):
    print("b is not")
# Out:
# b is not

# %%
#if
#if else
#pass

# %%
n=int(input("enter a nuber"))
for i in range(1,11):
  print(n*i )
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
for i in range(10,0,-1):
    for j in range(5):
        print(i, j, sep="--")
# Out:
# 10--0
# 10--1
# 10--2
# 10--3
# 10--4
# 9--0
# 9--1
# 9--2
# 9--3
# 9--4
# 8--0
# 8--1
# 8--2
# 8--3
# 8--4
# 7--0
# 7--1
# 7--2
# 7--3
# 7--4
# 6--0
# 6--1
# 6--2
# 6--3
# 6--4
# 5--0
# 5--1
# 5--2
# 5--3
# 5--4
# 4--0
# 4--1
# 4--2
# 4--3
# 4--4
# 3--0
# 3--1
# 3--2
# 3--3
# 3--4
# 2--0
# 2--1
# 2--2
# 2--3
# 2--4
# 1--0
# 1--1
# 1--2
# 1--3
# 1--4

# %%
#LOOPs

# %%
c="y"
while(c!= "x"):
    c= input("Any charecter and x to exit")

# %%
c="y"
while(c!= "x"):
    c= input("Any charecter and x to exit")

# %%
str= "python Program"
print(str[-1:5:2])
# Out:
# pto

# %%
str= "python Program"
print(str[-1::-1])
# Out:
# margorP nohtyp

# %%
str="python program"
l=0
for x in str:
    l=l+1
print(l)
# Out:
# 14

# %%
print(ord("A"))
# Out:
# 65
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 print(ord("A"))
# ----> 2 print(char(65))
#
# NameError: name 'char' is not defined
