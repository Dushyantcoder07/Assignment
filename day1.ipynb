# %%
print("helllo","python", sep="-",end=" ")
print('hey')
# Out:
# helllo-python hey

# %%
print("""python isiesay
      python not easy""")
# Out:
# python isiesay
#       python not easy

# %%
a="dushyant"
print(a,(type(a)))
# Out:
# dushyant <class 'str'>

# %%
a=10
print(a,type(a))
b='dushyant'
print(b,type(b))
# Out:
# 10 <class 'int'>
# dushyant <class 'str'>

# %%
a=20
print(id(a))
b=20.0
print(id(b))
# Out:
# 140710924944904
# 1953479401712

# %%
a=10
b=int(10.0)
print(id(a),id(b))
# Out:
# 140710924944584 140710924944584

# %%
a=10
b=20
print(id(a),id(b))
# Out:
# 140710924944584 140710924944904

# %%
n1=input("Enter the number1:")
print(n1)
# Out:
# 20

# %%
n1=input("Enter the number1:")
print(type(n1))
# Out:
# <class 'str'>
