# %%
dict1={1:'python',2:'java',3:'c++'}
dict2= dict1.copy()
print(dict1)
print(dict2.get(1))
print(dict2.items())
print(dict2.keys())
dict2.pop(3)
print(dict2)
dict2.popitem()
print(dict2)
# Out:
# {1: 'python', 2: 'java', 3: 'c++'}
# python
# dict_items([(1, 'python'), (2, 'java'), (3, 'c++')])
# dict_keys([1, 2, 3])
# {1: 'python', 2: 'java'}
# {1: 'python'}

# %%
p=[1,2,3,4]
d={1:"abc"}
t=(1,2,3,4)
print(t[1])
l=len(t)

for x in range(l):
    print(t[x])
# Out:
# 2
# 1
# 2
# 3
# 4

# %%
t=(1,2,3,4)
print(t[1:])
print(t[::-1])
print(t[2:4])
# Out:
# (2, 3, 4)
# (4, 3, 2, 1)
# (3, 4)

# %%
d=(10,20,30,40,50)
print(min(d))
print(max(d))
print(d.count(20))
print(d.index(40))
print(sum(d))
# Out:
# 10
# 50
# 1
# 3
# 150

# %%
s={"apple","banana","cherry",True,1}
s.add("mango")
# Out:
# {True, 'banana', 'cherry', 'apple', 'mango'} <class 'set'>

# %%
s1={"apply","banana","key"}
s2={1,2,"abc"}
s3=s1.union(s2)
print(s3)
s4=s1|s2
print(s4)
# Out:
# {'key', 1, 2, 'apply', 'abc', 'banana'}
# {'key', 1, 2, 'apply', 'abc', 'banana'}

# %%
s1=set()
s2=set()

for i in range(5):
    s1.add(i)
for i in range(3,9):
    s2.add(i)
s3=s1.intersection(s2)
print(s3)
s4=s1&s2
print(s4)
s5=s1-s2
print(s5)

print(s1==s2)
# Out:
# {3, 4}
# {3, 4}
# {0, 1, 2}
# False

# %%
def function1(n1,n2):
    print("Example of function")

function1(20,30)
# Out:
# Example of function

# %%
def function2(*city):
    print(city)
    print(city[1])

function2("jaipur","dehli","italy")
# Out:
# ('jaipur', 'dehli', 'italy')
# dehli

# %%
def function3(city3,city2,city1):
    print(city1)

function3(city1="jaipur",city2="dehli",city3="italy")
# Out:
# jaipur

# %%
def function4(**city):
    print(city['city2'])

function4(city1="jaipur",city2="dehli")
# Out:
# dehli

# %%
def function5(city="jaipur"):
    print(city)

function5()
function5("new dehli")
# Out:
# jaipur
# new dehli

# %%
def function6(fruit):
    for x in fruit:
        print(x)
    

fruit=["apple","banana","cherry"]
function6(fruit)
# Out:
# apple
# banana
# cherry

# %%
def dob(n1):
    return n1*2

x= dob(20)
print(dob(30))
print(x)
# Out:
# 60
# 40

# %%
def dob(n1, /):
    print(n1*2)

dob(5)
# Out:
# 10

# %%
def dob(*,n1):
    print(n1*2)

dob(n1=5)
# Out:
# 10

# %%
def dob(a,b,/,*,c,d):
    print(a+b+c+d)

dob(5,6,c=7,d=8)
# Out:
# 26

# %%
def rec(k):
    if k>0:
        print(k)
        k=k-1
        rec(k)
    else:
        print(k)

rec(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
file=open("first.txt","w")
file.write("this is my first file in python\n")
file.write("file is good\n")
file.close()

# %%
file = open("first.txt","r")
for x in file:
    print(x)
# Out:
# this is my first fike in python
#
# file is good

# %%
file = open("first.txt","r")
print(file.read())
# Out:
# this is my first fike in python
# file is good

# %%
with open("first.txt","r") as file:
    data=file.read()

    print(data)
# Out:
# this is my first fike in python
# file is good

# %%
file= open("first.txt","r")
print(file.read(5))
# Out:
# this

# %%
with open("first.txt") as file:
    data=file.readlines()
for line in data:
    word=line.split()

    print(word)
# Out:
# ['this', 'is', 'my', 'first', 'fike', 'in', 'python']
# ['file', 'is', 'good']
